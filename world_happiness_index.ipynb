# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('world_happiness_index.csv')
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# There is no as such null values found in the whole data.

# %%
data.drop(['Happiness Rank','Country','Region'],inplace=True,axis=1)

# %%
data
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# 'Happiness Rank','Country','Region' does not influence the happiness score, so we drop those columns

# %%
data.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %%
data.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %% [markdown]
# Corelation of data with happiness score is been given.

# %%
plt.figure(figsize=(13,8))
sns.heatmap(data.corr(),color='Blue',annot=True)
plt.title('Correlation')
plt.show()

# %% [markdown]
# Most of the data are positively coorelated with happiness score except few.

# %%
data.plot(kind='box',subplots=True,layout=(3,3),figsize=(10,8))
# Out:
# Happiness Score                     AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Standard Error                   AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Economy (GDP per Capita)         AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# Family                              AxesSubplot(0.125,0.391471;0.227941x0.222059)
# Health (Life Expectancy)         AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# Freedom                          AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# Trust (Government Corruption)          AxesSubplot(0.125,0.125;0.227941x0.222059)
# Generosity                          AxesSubplot(0.398529,0.125;0.227941x0.222059)
# Dystopia Residual                   AxesSubplot(0.672059,0.125;0.227941x0.222059)
# dtype: object

# %%
data
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# We can see some outliers in the given dataset, so we apply Z-score to remove it.

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(data))
z
# Out:
# array([[1.93736005, 0.80592569, 1.36962124, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.91458063, 0.05588945, 1.13522625, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.88479215, 0.8544869 , 1.19286069, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [2.0761992 , 0.13253425, 0.45524543, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [2.1646885 , 2.26396166, 2.06756644, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [2.22251319, 1.13418227, 1.58633379, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
data=data[(z<3).all(axis=1)]

# %%
data
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 150            3.655         0.05141                   0.46534  0.77115
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 156            2.905         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
percentage=(158-149)/158*100
print ('Percentage loss of data:',percentage)
# Out:
# Percentage loss of data: 5.69620253164557

# %%
data.plot(kind='box',layout=(3,3),subplots=True,figsize=(10,8))
# Out:
# Happiness Score                     AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Standard Error                   AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Economy (GDP per Capita)         AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# Family                              AxesSubplot(0.125,0.391471;0.227941x0.222059)
# Health (Life Expectancy)         AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# Freedom                          AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# Trust (Government Corruption)          AxesSubplot(0.125,0.125;0.227941x0.222059)
# Generosity                          AxesSubplot(0.398529,0.125;0.227941x0.222059)
# Dystopia Residual                   AxesSubplot(0.672059,0.125;0.227941x0.222059)
# dtype: object

# %%
y=data['Happiness Score']
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
x=data.drop('Happiness Score',axis=1)
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 150         0.05141                   0.46534  0.77115
# 151         0.04324                   0.25812  0.85188
# 152         0.03084                   0.31982  0.30285
# 154         0.03656                   0.28665  0.35386
# 156         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
x.shape
# Out:
# (149, 8)

# %%
y.shape
# Out:
# (149,)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0          0.196283                  0.892961  0.952046
# 1          0.381263                  0.832733  1.000000
# 2          0.185860                  0.847542  0.962115
# 3          0.255180                  0.932918  0.935163
# 4          0.214115                  0.848060  0.927577
# ..              ...                       ...       ...
# 144        0.413538                  0.297549  0.425967
# 145        0.310938                  0.165048  0.499400
# 146        0.155218                  0.204500  0.000000
# 147        0.227050                  0.183291  0.046399
# 148        0.855205                  0.009783  0.102803
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    0.918244  0.993789                       0.853038
# 1                    0.924496  0.938841                       0.287442
# 2                    0.853099  0.969615                       0.982666
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=.8,random_state=50)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.9999999432339106

# %%
predlr=lr.predict(x_test)
print(r2_score(y_test,predlr))
# Out:
# 0.9999999087113559

# %%
from sklearn.svm import SVR

# %%
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    sv.score(x_train,y_train)
    pred=sv.predict(x_test)
    print(r2_score(y_test,pred))
# Out:
# 0.9971080958906063
# 0.9399352352868813
# 0.9749151808204543

# %%
import pickle

# %%
filename='Happiness_index.pkl'
pickle.dump(lr,open('Happiness_index.pkl','wb'))
