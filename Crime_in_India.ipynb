# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('C:/Users/HP/Desktop/10_Property_stolen_and_recovered.csv')
data
# Out:
#                       Area_Name  Year           Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Burglary - Property
# 1                Andhra Pradesh  2001  Burglary - Property
# 2             Arunachal Pradesh  2001  Burglary - Property
# 3                         Assam  2001  Burglary - Property
# 4                         Bihar  2001  Burglary - Property
# ...                         ...   ...                  ...
# 2444                 Tamil Nadu  2010       Total Property
# 2445                    Tripura  2010       Total Property
# 2446              Uttar Pradesh  2010       Total Property
# 2447                Uttarakhand  2010       Total Property
# 2448                West Bengal  2010       Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 0                              3. Burglary                        27
# 1                              3. Burglary                      3321
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2449 entries, 0 to 2448
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Area_Name                    2449 non-null   object
#  1   Year                         2449 non-null   int64
#  2   Group_Name                   2449 non-null   object
#  3   Sub_Group_Name               2449 non-null   object
#  4   Cases_Property_Recovered     2449 non-null   int64
#  5   Cases_Property_Stolen        2449 non-null   int64
#  6   Value_of_Property_Recovered  2449 non-null   int64
#  7   Value_of_Property_Stolen     2449 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 153.2+ KB

# %%
data.shape
# Out:
# (2449, 8)

# %% [markdown]
# Number of Rows and columns are detected.

# %%
data['Area_Name'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %% [markdown]
# Under the column Area name, we checked any duplicate values are present or not.

# %%
data['Group_Name'].unique()
# Out:
# array(['Burglary - Property', 'Criminal Breach of Trust - Property',
#        'Dacoity -Property', 'Other heads of Property',
#        'Robbery - Property', 'Theft - Property', 'Total Property'],
#       dtype=object)

# %% [markdown]
# Under the column name Group name, we checked the type of crimes were grouped.

# %%
data['Sub_Group_Name'].unique()
# Out:
# array(['3. Burglary', '5. Criminal Breach of Trust', '1. Dacoity',
#        '6. Other Property', '2. Robbery', '4. Theft',
#        '7. Total Property Stolen & Recovered'], dtype=object)

# %% [markdown]
# Sub-group of crimes are also grouped under different column.

# %%
data.isnull().sum()
# Out:
# Area_Name                      0
# Year                           0
# Group_Name                     0
# Sub_Group_Name                 0
# Cases_Property_Recovered       0
# Cases_Property_Stolen          0
# Value_of_Property_Recovered    0
# Value_of_Property_Stolen       0
# dtype: int64

# %% [markdown]
# Checked whether any null values are present in the dataset. There was no null values detected.

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Absence of null value can be visualize through the heatmap

# %%
data.describe()
# Out:
#               Year  Cases_Property_Recovered  Cases_Property_Stolen  \
# count  2449.000000               2449.000000            2449.000000
# mean   2005.499388               1232.892201            3419.420988
# std       2.873294               3079.573907            8136.256820
# min    2001.000000                  0.000000               0.000000
# 25%    2003.000000                 13.000000              45.000000
# 50%    2005.000000                113.000000             358.000000
# 75%    2008.000000                722.000000            1875.000000
# max    2010.000000              27960.000000           80663.000000
#
#        Value_of_Property_Recovered  Value_of_Property_Stolen
# count                 2.449000e+03              2.449000e+03
# mean                  5.859924e+07              2.465431e+08
# std                   2.494403e+08              9.670035e+08
# min                   0.000000e+00              0.000000e+00
# ...

# %%
data.corr()
# Out:
#                                  Year  Cases_Property_Recovered  \
# Year                         1.000000                  0.022467
# Cases_Property_Recovered     0.022467                  1.000000
# Cases_Property_Stolen        0.028893                  0.935765
# Value_of_Property_Recovered  0.099033                  0.495588
# Value_of_Property_Stolen     0.100732                  0.579084
#
#                              Cases_Property_Stolen  \
# Year                                      0.028893
# Cases_Property_Recovered                  0.935765
# Cases_Property_Stolen                     1.000000
# Value_of_Property_Recovered               0.508971
# Value_of_Property_Stolen                  0.643448
#
#                              Value_of_Property_Recovered  \
# Year                                            0.099033
# Cases_Property_Recovered                        0.495588
# Cases_Property_Stolen                           0.508971
# ...

# %% [markdown]
# We checked the correlation between different columns.

# %%
plt.figure(figsize=(10,8))
plt.title('Correlation')
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# Some positive correaltion between value of property stolen and value of property recovered.
# There is also strong correaltion between Cases property recovered and Cases property stolen.
# We can also see some correlation between Cases property Recovered and value of property recovered.

# %%
data['Cases_Property_Recovered'].sum()
# Out:
# 3019353

# %% [markdown]
# Total number of Cases of property that are recovered from all the union Territory and states during 2001 to 2010.

# %%
data['Cases_Property_Stolen'].sum()
# Out:
# 8374162

# %% [markdown]
# Total number of Cases of property that are stolen from all the union Territory and states during 2001 to 2010.

# %%
data['Value_of_Property_Recovered'].sum()
# Out:
# 143509540619

# %% [markdown]
# Total value of property that are recovered from all the union Territory and states during 2001 to 2010.

# %%
data['Value_of_Property_Stolen'].sum()
# Out:
# 603784038161

# %% [markdown]
# Total value of property that are stolen from all the union Territory and states during 2001 to 2010.

# %%
max_cases=data.sort_values('Cases_Property_Stolen',ascending=False).head(10)
max_cases
# Out:
#         Area_Name  Year      Group_Name                        Sub_Group_Name  \
# 2434  Maharashtra  2010  Total Property  7. Total Property Stolen & Recovered
# 2364  Maharashtra  2008  Total Property  7. Total Property Stolen & Recovered
# 2399  Maharashtra  2009  Total Property  7. Total Property Stolen & Recovered
# 2329  Maharashtra  2007  Total Property  7. Total Property Stolen & Recovered
# 2260  Maharashtra  2005  Total Property  7. Total Property Stolen & Recovered
# 2295  Maharashtra  2006  Total Property  7. Total Property Stolen & Recovered
# 2225  Maharashtra  2004  Total Property  7. Total Property Stolen & Recovered
# 2120  Maharashtra  2001  Total Property  7. Total Property Stolen & Recovered
# 2155  Maharashtra  2002  Total Property  7. Total Property Stolen & Recovered
# 2190  Maharashtra  2003  Total Property  7. Total Property Stolen & Recovered
#
#       Cases_Property_Recovered  Cases_Property_Stolen  \
# 2434                     27960                  80663
# ...

# %% [markdown]
# Top 10 value of cases of property stolen in different States and Union Territory

# %%
max_value_stolen=data.sort_values('Value_of_Property_Stolen',ascending=False).head(10)
max_value_stolen
# Out:
#            Area_Name  Year                           Group_Name  \
# 2434     Maharashtra  2010                       Total Property
# 2364     Maharashtra  2008                       Total Property
# 2399     Maharashtra  2009                       Total Property
# 685      Maharashtra  2010  Criminal Breach of Trust - Property
# 2329     Maharashtra  2007                       Total Property
# 2155     Maharashtra  2002                       Total Property
# 2433  Madhya Pradesh  2010                       Total Property
# 2388           Delhi  2009                       Total Property
# 2295     Maharashtra  2006                       Total Property
# 1034  Madhya Pradesh  2010                    Dacoity -Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 2434  7. Total Property Stolen & Recovered                     27960
# 2364  7. Total Property Stolen & Recovered                     26935
# ...

# %% [markdown]
# Top 10 values of property stolen in different years in different States and Union Territory

# %%
max_cases_recovered=data.sort_values('Cases_Property_Recovered',ascending=False).head(10)
max_cases_recovered
# Out:
#         Area_Name  Year      Group_Name                        Sub_Group_Name  \
# 2434  Maharashtra  2010  Total Property  7. Total Property Stolen & Recovered
# 2364  Maharashtra  2008  Total Property  7. Total Property Stolen & Recovered
# 2399  Maharashtra  2009  Total Property  7. Total Property Stolen & Recovered
# 2329  Maharashtra  2007  Total Property  7. Total Property Stolen & Recovered
# 2295  Maharashtra  2006  Total Property  7. Total Property Stolen & Recovered
# 2260  Maharashtra  2005  Total Property  7. Total Property Stolen & Recovered
# 2225  Maharashtra  2004  Total Property  7. Total Property Stolen & Recovered
# 2120  Maharashtra  2001  Total Property  7. Total Property Stolen & Recovered
# 2190  Maharashtra  2003  Total Property  7. Total Property Stolen & Recovered
# 2155  Maharashtra  2002  Total Property  7. Total Property Stolen & Recovered
#
#       Cases_Property_Recovered  Cases_Property_Stolen  \
# 2434                     27960                  80663
# ...

# %% [markdown]
# Top 10 value of cases of property recovered in different years in different States and Union Territory

# %%
max_value_recovered=data.sort_values('Value_of_Property_Recovered',ascending=False).head(10)
max_value_recovered
# Out:
#            Area_Name  Year         Group_Name  \
# 2433  Madhya Pradesh  2010     Total Property
# 1034  Madhya Pradesh  2010  Dacoity -Property
# 2434     Maharashtra  2010     Total Property
# 2329     Maharashtra  2007     Total Property
# 2399     Maharashtra  2009     Total Property
# 2364     Maharashtra  2008     Total Property
# 2155     Maharashtra  2002     Total Property
# 2448     West Bengal  2010     Total Property
# 2376   Uttar Pradesh  2008     Total Property
# 2295     Maharashtra  2006     Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 2433  7. Total Property Stolen & Recovered                     11549
# 1034                            1. Dacoity                        81
# 2434  7. Total Property Stolen & Recovered                     27960
# 2329  7. Total Property Stolen & Recovered                     25106
# 2399  7. Total Property Stolen & Recovered                     26097
# ...

# %% [markdown]
# Top 10 value of property recovered in different years in different States and Union Territory

# %%
count_data=data.groupby('Area_Name')[['Cases_Property_Recovered','Cases_Property_Stolen','Value_of_Property_Recovered','Value_of_Property_Stolen']].sum()
count_data
# Out:
#                            Cases_Property_Recovered  Cases_Property_Stolen  \
# Area_Name
# Andaman & Nicobar Islands                      1516                   3662
# Andhra Pradesh                               332510                 642822
# Arunachal Pradesh                              6048                  16632
# Assam                                         54784                 245560
# Bihar                                         63876                 411840
# Chandigarh                                    15188                  39720
# Chhattisgarh                                  68912                 199712
# Dadra & Nagar Haveli                           1170                   2642
# Daman & Diu                                     534                   2056
# Delhi                                        157858                 490694
# Goa                                            5884                  19788
# ...

# %% [markdown]
# The total counts of all the values of stolen property that are recovered, values of property that were stolen, number of cases registered and number of cases of recovered property are given according to the states and Union Territory.

# %%
a=np.array(data['Year'])
b=np.array(data['Cases_Property_Stolen'])

# %%
plt.figure(figsize=(10,7))
plt.title('Property Stolen in the following years')
plt.xlabel(a)
plt.ylabel(b)
plt.bar(a,b,color='r')
plt.show()

# %% [markdown]
# We can evident from the above bar graph that the cases for property stolen has increased every year.

# %%
a=np.array(data['Year'])
b=np.array(data['Cases_Property_Recovered'])

# %%
plt.figure(figsize=(10,7))
plt.title('Property Recovered in the following years')
plt.xlabel(a)
plt.ylabel(b)
plt.bar(a,b,color='y')
plt.show()

# %% [markdown]
# We can see from the above visualization that the cases of property had also increased gradually from 2001 to 2010.

# %%
a=np.array(data['Year'])
b=np.array(data['Value_of_Property_Recovered'])

# %%
plt.figure(figsize=(10,7))
plt.title('value of Property Recovered in the following years')
plt.xlabel(a)
plt.ylabel(b)
plt.bar(a,b,color='violet')
plt.show()

# %% [markdown]
# If you compare with the bar graph of both the value of property stolen with property recovered than it can be understood that that the amount is low almost in all the year except 2010.

# %%
a=np.array(data['Year'])
b=np.array(data['Value_of_Property_Stolen'])

# %%
plt.figure(figsize=(10,7))
plt.title('value of Property stolen in the following years')
plt.xlabel(a)
plt.ylabel(b)
plt.bar(a,b,color='blue')
plt.show()

# %% [markdown]
# Through the above visulaization,we can see the increase in value of stolen property during 2001 to 2010.
